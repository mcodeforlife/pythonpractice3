# %%
import numpy as np

# %%
a= np.array([1,2,3,4])

# %%
a1 = np.array([[1,2],[3,4]])
print(a1)
# Out:
# [[1 2]
#  [3 4]]

# %%
a_ravel = a1.ravel()
print(a_ravel)
# Out:
# [1 2 3 4]

# %%
print(a1)
# Out:
# [[1 2]
#  [3 4]]

# %%
b = a1.flatten()
print(b)
# Out:
# [1 2 3 4]

# %%
print(a1.__array_interface__['data'][0])
print(b.__array_interface__['data'][0])
# Out:
# 1865685999360
# 1865685998976

# %%
a2 = np.array([[1,2,3],[4,5,6]])

# %%
print(a2)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
a2.resize((3,3), refcheck=False)
print(a2)
# Out:
# [[1 2 3]
#  [4 5 6]
#  [0 0 0]]

# %%
b2 = np.array([[1],[2],[3]])
print(b2.shape)
# Out:
# (3, 1)

# %%
b3 = np.squeeze(b2)
print(b3.shape)
# Out:
# (3,)

# %%
mat = np.array([[1,2,3],
                [3,4,5],
                [7,8,9]])

# %%
print(mat[0][1])
# Out:
# 2

# %%
mat[:,2]
# Out:
# array([3, 5, 9])

# %%
#[[1,2,3],
#[3,4,5],
#[7,8,9]])

# %%
mat[::-1,::-1]
# Out:
# array([[9, 8, 7],
#        [5, 4, 3],
#        [3, 2, 1]])

# %%
arr = np.array([5,4,6,7,89,10])

# %%
l = []
for i in arr:
    if i>15:
        l.append(i)
l=np.array(l)
print(l)
# Out:
# [89]

# %%
arr[arr>15]
# Out:
# array([89])
